# %% [markdown]
# ![image.png](attachment:a8db4ef7-2f15-4628-b3e1-fac1f52f1c95.png)

# %%
from sympy import symbols, Function, Eq, rsolve

# 변수 및 함수 정의
k = symbols('k', integer=True)
y = Function('y')

# 차분 방정식 정의
diff_eq = Eq(y(k+1) - 2*y(k), 0)

# 초기 조건 추가(딕셔너리 자료형)
init_conditions = {y(0): 1}

# 해 구하기
solution = rsolve(diff_eq, y(k),init_conditions)
solution
# Out:
# 2**k

# %% [markdown]
# ![image.png](attachment:d1093796-8340-48a3-8f79-727386c35c8c.png)

# %%
# 차분 방정식 정의
diff_eq = Eq(y(k+2)-3*y(k+1)+2*y(k), 0)

# 초기 조건 추가(딕셔너리 자료형)
init_conditions = {y(0): 2,y(1):5}

# 해 구하기
solution = rsolve(diff_eq, y(k),init_conditions)
solution
# Out:
# 3*2**k - 1
